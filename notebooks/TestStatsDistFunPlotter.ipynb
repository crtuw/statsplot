# %%
import sys
sys.path.insert(0, '..')

# %%
loc = "0.0"
scale = "1.0"
dlim = "2.0"
ctp = "0.999"

# %%
from source.dashboards import create_distfun_dashboard
sampleDashboard = create_distfun_dashboard(loc, scale, dlim, ctp)
