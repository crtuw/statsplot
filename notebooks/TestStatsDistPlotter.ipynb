# %%
import sys
sys.path.insert(0, '..')

# %%
loc = "0.0"
scale = "1.0"
n = "40"

# %%
from source.StatsDistSampleDashboard import StatsDistSampleDashboard
from source.StatsDistFunArtist import StatsDistFunArtist
from source.StatsSampleArtist import StatsSampleArtist

from scipy.stats import norm
dist = norm(loc=float(loc), scale=float(scale))
sample = dist.rvs(int(n))

statsSampleArtist = StatsSampleArtist(sample = sample)
statsDistFunArtist = StatsDistFunArtist(dist = dist)

statsDistFunArtist.kwargs_fillstyle = dict(color="lightgrey")

StatsDistSampleDashboard(statsSampleArtist=statsSampleArtist, 
                         statsDistFunArtist=statsDistFunArtist).plot_all()
