# %%
import sys
sys.path.insert(0, '..')

# %%
loc = "0.0"
scale = "1.0"
n = "40"
dlim = "3."
ctp = "0.99"

# %%
from source.dashboards import create_dist_sample_dashboard
sampleDashboard = create_dist_sample_dashboard(loc, scale, n, dlim, ctp)
# Out:
# {'ll': 0.0050000000000000044, 'ul': 0.995, 'lref': 'lbtp', 'uref': 'ubtp'}
